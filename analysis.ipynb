# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data = pd.read_csv('india_job_market_dataset.csv')
df = data
print(df.head(5))
# Out:
#   Job ID            Job Title Company Name Job Location    Job Type  \
# 0   JOB1    Software Engineer       Amazon    Ahmedabad   Full-time
# 1   JOB2  Marketing Executive      Infosys    Ahmedabad  Internship
# 2   JOB3    Financial Analyst     Deloitte       Jaipur    Contract
# 3   JOB4     Business Analyst       Amazon        Delhi   Full-time
# 4   JOB5    Software Engineer      Infosys        Delhi   Full-time
#
#   Salary Range Experience Required Posted Date Application Deadline  \
# 0      5-8 LPA           2-5 years  2025-01-16           2025-01-25
# 1      5-8 LPA           2-5 years  2024-12-25           2025-01-19
# 2      20+ LPA          5-10 years  2025-01-22           2025-01-29
# 3      20+ LPA           2-5 years  2025-01-07           2025-02-06
# 4    12-20 LPA           10+ years  2024-12-26           2025-01-08
#
#    Job Portal  Number of Applicants Education Requirement  \
# 0    LinkedIn                    23                   PhD
# ...

# %%
print("\nDataset Info:")
data.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job ID                 20000 non-null  object
#  1   Job Title              20000 non-null  object
#  2   Company Name           20000 non-null  object
#  3   Job Location           20000 non-null  object
#  4   Job Type               20000 non-null  object
#  5   Salary Range           20000 non-null  object
#  6   Experience Required    20000 non-null  object
#  7   Posted Date            20000 non-null  object
#  8   Application Deadline   20000 non-null  object
#  9   Job Portal             20000 non-null  object
#  10  Number of Applicants   20000 non-null  int64
#  11  Education Requirement  20000 non-null  object
#  12  Skills Required        20000 non-null  object
#  13  Remote/Onsite          20000 non-null  object
# ...

# %%
print("Missing values: \n")
print(data.isnull().sum())
# Out:
# Missing values:
#
# Job ID                   0
# Job Title                0
# Company Name             0
# Job Location             0
# Job Type                 0
# Salary Range             0
# Experience Required      0
# Posted Date              0
# Application Deadline     0
# Job Portal               0
# Number of Applicants     0
# Education Requirement    0
# Skills Required          0
# Remote/Onsite            0
# Company Size             0
# dtype: int64

# %%
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#        Number of Applicants
# count          20000.000000
# mean             256.723300
# std              141.745833
# min               10.000000
# 25%              134.000000
# 50%              258.000000
# 75%              380.000000
# max              500.000000

# %%
print("\nColumns in the dataset:")
print(data.columns)
# Out:
# Columns in the dataset:
# Index(['Job ID', 'Job Title', 'Company Name', 'Job Location', 'Job Type',
#        'Salary Range', 'Experience Required', 'Posted Date',
#        'Application Deadline', 'Job Portal', 'Number of Applicants',
#        'Education Requirement', 'Skills Required', 'Remote/Onsite',
#        'Company Size'],
#       dtype='object')

# %%
df = pd.DataFrame(data)
print("Sample Dataset:\n", df)
# Out:
# Sample Dataset:
#           Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %% [markdown]
# printing diff counts

# %%
print("\n Job Titles and no. of requirements:")
job_title_counts = df['Job Title'].value_counts()
print(job_title_counts)
# Out:
#  Job Titles and no. of requirements:
# Cyber Security Analyst    2085
# Marketing Executive       2036
# Graphic Designer          2013
# Financial Analyst         2008
# Product Manager           2006
# Business Analyst          1989
# Data Scientist            1976
# HR Manager                1974
# Software Engineer         1971
# Sales Representative      1942
# Name: Job Title, dtype: int64

# %%
print("\n Job Location and no. of requirement their:")
job_location_counts = df['Job Location'].value_counts()
print(job_location_counts)
# Out:
#  Job Location and no. of requirement their:
# Hyderabad    2055
# Bangalore    2023
# Ahmedabad    2019
# Jaipur       2019
# Chennai      2018
# Noida        1993
# Delhi        1990
# Pune         1970
# Mumbai       1958
# Kolkata      1955
# Name: Job Location, dtype: int64

# %%
print("\n Job type and no. of availability")
job_type_counts = df['Job Type'].value_counts()
print(job_type_counts)
# Out:
#  Job type and no. of availability
# Part-time     5111
# Internship    5085
# Full-time     4981
# Contract      4823
# Name: Job Type, dtype: int64

# %%
print("\n Company name and  and no. of Job there:")
company_name_counts = df['Company Name'].value_counts()
print(company_name_counts)
# Out:
#  Company name and  and no. of Job there:
# Amazon       2086
# Wipro        2069
# HCL          2023
# Google       2004
# Deloitte     1983
# Infosys      1981
# TCS          1979
# Microsoft    1977
# Accenture    1954
# IBM          1944
# Name: Company Name, dtype: int64

# %%
print("\n Company name and education requiremnet there:")

company_name_and_education_requirement = df.groupby(['Company Name', 'Education Requirement']).size()

print(company_name_and_education_requirement)
# Out:
#  Company name and education requiremnet there:
# Company Name  Education Requirement
# Accenture     B.Sc                     392
#               B.Tech                   398
#               M.Tech                   397
#               MBA                      401
#               PhD                      366
# Amazon        B.Sc                     416
#               B.Tech                   413
#               M.Tech                   397
#               MBA                      437
#               PhD                      423
# Deloitte      B.Sc                     400
#               B.Tech                   383
#               M.Tech                   418
#               MBA                      363
#               PhD                      419
# Google        B.Sc                     413
#               B.Tech                   414
#               M.Tech                   414
#               MBA                      404
#               PhD                      359
# ...

# %%
print("\n Company name and remote/onsite there:")

company_name_and_remote_onsite = df.groupby(['Company Name', 'Remote/Onsite']).size()

print(company_name_and_remote_onsite)
# Out:
#  Company name and remote/onsite there:
# Company Name  Remote/Onsite
# Accenture     Hybrid           617
#               Onsite           682
#               Remote           655
# Amazon        Hybrid           689
#               Onsite           710
#               Remote           687
# Deloitte      Hybrid           621
#               Onsite           681
#               Remote           681
# Google        Hybrid           659
#               Onsite           656
#               Remote           689
# HCL           Hybrid           691
#               Onsite           684
#               Remote           648
# IBM           Hybrid           625
#               Onsite           642
#               Remote           677
# Infosys       Hybrid           608
#               Onsite           669
#               Remote           704
# Microsoft     Hybrid           630
#               Onsite           655
#               Remote           692
# TCS           Hybrid           709
# ...

# %%
print("\n Company name and Job type available there:")

company_name_and_job_typecounts = df.groupby(['Company Name', 'Job Type']).size()

print(company_name_and_job_typecounts)
# Out:
#  Company name and Job type available there:
# Company Name  Job Type
# Accenture     Contract      476
#               Full-time     503
#               Internship    516
#               Part-time     459
# Amazon        Contract      469
#               Full-time     529
#               Internship    551
#               Part-time     537
# Deloitte      Contract      502
#               Full-time     491
#               Internship    496
#               Part-time     494
# Google        Contract      458
#               Full-time     496
#               Internship    510
#               Part-time     540
# HCL           Contract      524
#               Full-time     513
#               Internship    475
#               Part-time     511
# IBM           Contract      470
#               Full-time     475
#               Internship    492
#               Part-time     507
# Infosys       Contract      483
#               Full-time     487
#               Internship    521
# ...

# %%
print("\n ob Portal and Job Location:")

job_portal_and_job_location_counts = df.groupby(['Job Portal', 'Job Location']).size()

print(job_portal_and_job_location_counts)
# Out:
#  ob Portal and Job Location:
# Job Portal  Job Location
# Indeed      Ahmedabad       715
#             Bangalore       682
#             Chennai         670
#             Delhi           692
#             Hyderabad       677
#             Jaipur          685
#             Kolkata         639
#             Mumbai          660
#             Noida           669
#             Pune            667
# LinkedIn    Ahmedabad       632
#             Bangalore       661
#             Chennai         630
#             Delhi           655
#             Hyderabad       656
#             Jaipur          657
#             Kolkata         640
#             Mumbai          638
#             Noida           638
#             Pune            646
# Naukri.com  Ahmedabad       672
#             Bangalore       680
#             Chennai         718
#             Delhi           643
#             Hyderabad       722
#             Jaipur          677
#             Kolkata         676
# ...

# %%
from collections import Counter

# Sample data (replace with the extracted text from your image)
text_data = """
Skills Required
C++, SQL, Python
SQL, C++, Python
arning, Excel, React
earning, Python, SQL
UI/UX, C++, Java
earning, Python, AWS
ct, Machine Learning
1, Digital Marketing
Excel, C++, React
Java, C++, Python
"""

# Split the text into lines and extract skills
skills = []
for line in text_data.splitlines():
    words = line.split()
    skills.extend(words)  # Add all words to the list directly

# Remove duplicates
distinct_skills = list(set(skills))

print("Distinct Skills:")
print(distinct_skills)
# Out:
# Distinct Skills:
# ['Digital', 'ct,', 'Python', 'Java,', 'AWS', 'Required', 'SQL,', 'arning,', 'Skills', 'Python,', 'earning,', 'UI/UX,', 'Machine', 'Learning', 'C++,', '1,', 'Excel,', 'SQL', 'Marketing', 'React', 'Java']

# %% [markdown]
# Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# 1. Count plot for a categorical column 
if 'Job Type' in data.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(y='Job Type', data=data, order=data['Job Type'].value_counts().index)
    plt.title("Job Category Distribution")
    plt.xlabel("Count")
    plt.ylabel("Job type")
    plt.show()

# %%
# 2. Salary distribution (replace 'Salary' with actual column name)
if 'Salary Range' in data.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(data['Salary Range'], bins=30, kde=True)
    plt.title("Salary Distribution")
    plt.xlabel("Salary")
    plt.ylabel("Frequency")
    plt.show()

# %%
# 3. Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\tarul\AppData\Local\Temp\ipykernel_11136\2144475162.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')

# %%
# 4. Bar plot for jobs by region (replace 'Region' with actual column name)
if 'Job Location' in data.columns:
    plt.figure(figsize=(10, 6))
    region_counts = data['Job Location'].value_counts()
    sns.barplot(x=region_counts.index, y=region_counts.values)
    plt.title("Job by Location")
    plt.xlabel("Location")
    plt.ylabel("Number of Jobs")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Display dataset structure
data_info = {
    "shape": data.shape,
    "columns": data.columns.tolist(),
    "head": data.head(),
    "missing_values": data.isnull().sum(),
    "data_types": data.dtypes,
    "unique_values": {col: data[col].nunique() for col in data.columns},
    "sample_values": {col: data[col].unique()[:5].tolist() for col in data.columns}
}

data_info
# Out:
# {'shape': (20000, 15),
#  'columns': ['Job ID',
#   'Job Title',
#   'Company Name',
#   'Job Location',
#   'Job Type',
#   'Salary Range',
#   'Experience Required',
#   'Posted Date',
#   'Application Deadline',
#   'Job Portal',
#   'Number of Applicants',
#   'Education Requirement',
#   'Skills Required',
#   'Remote/Onsite',
#   'Company Size'],
#  'head':   Job ID            Job Title Company Name Job Location    Job Type  \
#  0   JOB1    Software Engineer       Amazon    Ahmedabad   Full-time
#  1   JOB2  Marketing Executive      Infosys    Ahmedabad  Internship
#  2   JOB3    Financial Analyst     Deloitte       Jaipur    Contract
#  3   JOB4     Business Analyst       Amazon        Delhi   Full-time
#  4   JOB5    Software Engineer      Infosys        Delhi   Full-time
#
#    Salary Range Experience Required Posted Date Application Deadline  \
#  0      5-8 LPA           2-5 years  2025-01-16           2025-01-25
# ...

# %%
sns.set(style="whitegrid", palette="muted")

# 1. Popular Job Locations
plt.figure(figsize=(10, 6))
job_locations = data['Job Location'].value_counts()
sns.barplot(x=job_locations.index, y=job_locations.values)
plt.title("Most Popular Job Locations")
plt.xlabel("Job Location")
plt.ylabel("Number of Job Postings")
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Top 10 Skills Required
plt.figure(figsize=(10, 6))
top_skills = data['Skills Required'].value_counts().head(10)
sns.barplot(y=top_skills.index, x=top_skills.values, orient="h")
plt.title("Top 10 Skills Required")
plt.xlabel("Number of Job Postings")
plt.ylabel("Skills Required")
plt.show()

# %%
# 3. Salary Range Distribution
plt.figure(figsize=(8, 6))
sns.countplot(y='Salary Range', data=data, order=data['Salary Range'].value_counts().index)
plt.title("Salary Range Distribution")
plt.xlabel("Count")
plt.ylabel("Salary Range")
plt.show()

# %%
# 4. Job Type Distribution
plt.figure(figsize=(8, 6))
sns.countplot(y='Job Type', data=data, order=data['Job Type'].value_counts().index)
plt.title("Job Type Distribution")
plt.xlabel("Count")
plt.ylabel("Job Type")
plt.show()

# %%
# 5. Experience Required vs. Number of Applicants
plt.figure(figsize=(10, 6))
sns.boxplot(x='Experience Required', y='Number of Applicants', data=data)
plt.title("Experience Required vs. Number of Applicants")
plt.xlabel("Experience Required")
plt.ylabel("Number of Applicants")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
 #Prepare data for classification
# Features: Select relevant columns
features = ['Job Title', 'Job Location', 'Salary Range', 'Experience Required', 'Skills Required']
target = 'Job Type'

# Encode categorical features and target
encoder = LabelEncoder()
data_encoded = data.copy()
for col in features + [target]:
    data_encoded[col] = encoder.fit_transform(data[col])

# %%
# Split data into train and test sets
X = data_encoded[features]
y = data_encoded[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train a Random Forest Classifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions and evaluation
y_pred = clf.predict(X_test)
classification_report_result = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

classification_report_result, accuracy
# Out:
# ('              precision    recall  f1-score   support\n\n           0       0.25      0.25      0.25      1447\n           1       0.23      0.22      0.23      1504\n           2       0.26      0.25      0.26      1570\n           3       0.25      0.26      0.26      1479\n\n    accuracy                           0.25      6000\n   macro avg       0.25      0.25      0.25      6000\nweighted avg       0.25      0.25      0.25      6000\n',
#  0.24733333333333332)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from imblearn.over_sampling import SMOTE

# %%
# Extract features from 'Skills Required' using CountVectorizer
vectorizer = CountVectorizer(max_features=100, stop_words='english')
skills_matrix = vectorizer.fit_transform(data['Skills Required']).toarray()
skills_df = pd.DataFrame(skills_matrix, columns=vectorizer.get_feature_names_out())

# %%
# Combine vectorized 'Skills Required' with other features
X_improved = pd.concat([data_encoded.drop(columns=['Skills Required', 'Job Type']), skills_df], axis=1)
y_improved = data_encoded['Job Type']

# %%
# Handle class imbalance with SMOTE
# Re-check and ensure all features are numeric
# Re-encode categorical features
encoded_features = X_improved.copy()
for col in encoded_features.select_dtypes(include='object').columns:
    encoded_features[col] = encoder.fit_transform(encoded_features[col])

# Ensure no non-numeric data
assert encoded_features.select_dtypes(include='object').empty, "Non-numeric data still exists in features!"

# Retry SMOTE with corrected numeric data
X_balanced, y_balanced = smote.fit_resample(encoded_features, y_improved)

# Split the balanced dataset into train and test sets
X_train_bal, X_test_bal, y_train_bal, y_test_bal = train_test_split(X_balanced, y_balanced, test_size=0.3, random_state=42)

# Train a new Random Forest model with balanced data
clf_balanced = RandomForestClassifier(random_state=42, n_estimators=200, max_depth=10)
clf_balanced.fit(X_train_bal, y_train_bal)

# Predictions and evaluation
y_pred_bal = clf_balanced.predict(X_test_bal)
classification_report_bal = classification_report(y_test_bal, y_pred_bal)
accuracy_bal = accuracy_score(y_test_bal, y_pred_bal)

classification_report_bal, accuracy_bal
# Out:
# ('              precision    recall  f1-score   support\n\n           0       0.27      0.26      0.26      1551\n           1       0.27      0.22      0.24      1561\n           2       0.25      0.27      0.26      1518\n           3       0.25      0.30      0.27      1504\n\n    accuracy                           0.26      6134\n   macro avg       0.26      0.26      0.26      6134\nweighted avg       0.26      0.26      0.26      6134\n',
#  0.25872187805673297)
